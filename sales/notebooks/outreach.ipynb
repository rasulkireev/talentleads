# %%
import httpx
import pandas as pd
import os
import re

# %%
# set directory path
dir_path = '../emails'

# iterate over each file in the directory
for file_name in os.listdir(dir_path):
    # read CSV file and convert to dataframe
    if file_name.endswith('.csv'):
        file_path = os.path.join(dir_path, file_name)
        df = pd.read_csv(file_path)

# %%
# Convert rows with multiple items into multiple rows.

# Split the comma-separated values into lists
df['names_of_the_contact_person'] = df['names_of_the_contact_person'].str.split(',')
df['emails'] = df['emails'].str.split(',')

# Explode the lists into separate rows
df = df.explode('names_of_the_contact_person', ignore_index=True)
df = df.explode('emails', ignore_index=True)

# Strip whitespace from the columns
df['names_of_the_contact_person'] = df['names_of_the_contact_person'].str.strip()
df['emails'] = df['emails'].str.strip()

# %%
# Fix emails - First round
df['emails'] = df['emails'] \
            .str.replace(' ', '') \
            .str.replace('[at]', '@') \
            .str.replace('[AT]', '@') \
            .str.replace('{at}', '@') \
            .str.replace('(at)', '@') \
            .str.replace('_at_', '@') \
            .str.replace('-at-', '@') \
            .str.replace('[dot]', '.') \
            .str.replace('(dot)', '.') \
            .str.replace('_dot_', '.')

# %%
# Check if email is valid first round

count_of_valid_emails = 0
count_of_invalid_emails = 0

for index, row in df.iterrows():
    email = str(row['emails']) 
    if(re.match(r"[^@]+@[^@]+\.[^@]+", email)):
        count_of_valid_emails += 1
        df.loc[index, "email_is_valid"] = True
    else:
        count_of_invalid_emails += 1
        df.loc[index, "email_is_valid"] = False
        
print(f"Num of Valid Emails = {count_of_valid_emails}")
print(f"Num of Invalid Emails = {count_of_invalid_emails}")
# Out:
# Num of Valid Emails = 268
# Num of Invalid Emails = 18

# %%
# Fix emails - Second round

df.loc[df["email_is_valid"] == False, "emails"] = df["emails"] \
            .str.replace('at', '@') \
            .str.replace('AT', '@') \
            .str.replace('dot', '.') \
            .str.replace('DOT', '.')

# %%
# Check if email is valid the second time

count_of_valid_emails = 0
count_of_invalid_emails = 0

for index, row in df.iterrows():
    email = str(row['emails']) 
    if(re.match(r"[^@]+@[^@]+\.[^@]+", email)):
        count_of_valid_emails += 1
        df.loc[index, "email_is_valid"] = True
    else:
        count_of_invalid_emails += 1
        df.loc[index, "email_is_valid"] = False
        
print(f"Num of Valid Emails = {count_of_valid_emails}")
print(f"Num of Invalid Emails = {count_of_invalid_emails}")
# Out:
# Num of Valid Emails = 280
# Num of Invalid Emails = 6

# %%
df
# Out:
#     names_of_the_contact_person                               emails
# 0                           NaN  first_name.last_name@brightspec.com  \
# 1                           NaN               careers@brightspec.com
# 2                           NaN                   info@takeone.video
# 3                           NaN               jsaewitz@masslight.com
# 4                        Aleksi                              aleksi@
# ..                          ...                                  ...
# 281                         NaN                    praful@sarama.app
# 282                         NaN                       jobs@bytro.com
# 283                   Joniel E.                     joniel@modash.io
# 284              Stevie Buckley            stevie.buckley@xapien.com
# 285                         NaN                apply@equitybytes.com
#
#                      name        company_homepage_link email_is_valid
# 0              BrightSpec  https://www.brightspec.com/           True
# 1              BrightSpec  https://www.brightspec.com/           True
# 2                 TakeOne   https://www.takeone.video/           True
# 3               MassLight        https://masslight.com           True
# 4          ClimateAligned                          NaN          False
# ..                    ...                          ...            ...
# 281                Sarama                          NaN           True
# 282                 Bytro           https://bytro.com/           True
# 283             Modash.io                          NaN           True
# 284             Xapien AI                          NaN           True
# 285  Equity Bytes Holding                          NaN           True
#
# [286 rows x 5 columns]

# %%
df
# Out:
#     names_of_the_contact_person                               emails
# 0                           NaN  first_name.last_name@brightspec.com  \
# 1                           NaN               careers@brightspec.com
# 2                           NaN                   info@takeone.video
# 3                           NaN               jsaewitz@masslight.com
# 4                        Aleksi                              aleksi@
# ..                          ...                                  ...
# 281                         NaN                    praful@sarama.app
# 282                         NaN                       jobs@bytro.com
# 283                   Joniel E.                     joniel@modash.io
# 284              Stevie Buckley            stevie.buckley@xapien.com
# 285                         NaN                apply@equitybytes.com
#
#                      name        company_homepage_link email_is_valid
# 0              BrightSpec  https://www.brightspec.com/           True
# 1              BrightSpec  https://www.brightspec.com/           True
# 2                 TakeOne   https://www.takeone.video/           True
# 3               MassLight        https://masslight.com           True
# 4          ClimateAligned                          NaN          False
# ..                    ...                          ...            ...
# 281                Sarama                          NaN           True
# 282                 Bytro           https://bytro.com/           True
# 283             Modash.io                          NaN           True
# 284             Xapien AI                          NaN           True
# 285  Equity Bytes Holding                          NaN           True
#
# [286 rows x 5 columns]
